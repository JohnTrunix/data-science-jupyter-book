# %% [markdown]
# # Stream Graph Chart
#
# ````{card}
#
# <br/>
#
# ::::{grid} 2
#
# :::{grid-item}
# :columns: 3
# :class: sd-m-auto
# <img src="../../images/streamgraph.png" width="300px"/>
#
# :::
#
# :::{grid-item}
# :columns: 8
# Also called: Lee Byron's Streamgraph
#
# A streamgraph, or stream graph, is a type of stacked area graph which is displaced around a central axis, resulting in a flowing, organic shape.
#
# <br/>
#
# Functions:
#
# {bdg-info-line}`Comparison` {bdg-info-line}`Distribution`
#
# :::
# ::::
#
# +++
#
# Credits:
# [DataVizProject](https://datavizproject.com/about/)
#
# ````

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.DataFrame(np.random.random((30,6)), columns=['Val1', 'Val2', 'Val3', 'Val4', 'Val5', 'Val6'] ,index=np.arange(1990, 2020))
df.head()
# Out:
#           Val1      Val2      Val3      Val4      Val5      Val6
# 1990  0.597336  0.614037  0.195183  0.689214  0.308344  0.498146
# 1991  0.800094  0.543191  0.597474  0.930932  0.106526  0.361841
# 1992  0.324940  0.631033  0.281045  0.488824  0.681732  0.014668
# 1993  0.953744  0.070962  0.858770  0.265730  0.016481  0.253955
# 1994  0.837485  0.634248  0.798976  0.420473  0.367934  0.492761

# %%
mpl.style.use('seaborn')
colors = ['#002855', '#023E7D', '#376996', '#829CBC', '#FBD87F', '#F8C23A']
fig, ax = plt.subplots(figsize=(8, 6))

ax.stackplot(df.index, df.Val1, df.Val2, df.Val3, df.Val4, df.Val5, df.Val6, baseline="sym", colors=colors)
plt.xlim(df.index.min(), df.index.max())
plt.show()
