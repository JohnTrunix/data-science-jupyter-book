# %% [markdown]
# # Chord Chart
#
# ````{card}
#
# <br/>
#
# ::::{grid} 2
#
# :::{grid-item}
# :columns: 3
# :class: sd-m-auto
# <img src="../images/chord.png" width="300px"/>
#
# :::
#
# :::{grid-item}
# :columns: 8
# Also called: Chord Layout
#
# A chord diagram is a graphical method of displaying the inter-relationships between data in a matrix. The data is arranged radially around a circle with the relationships between the points typically drawn as arcs connecting the data together.
#
# <br/>
#
# Functions:
#
# {bdg-info-line}`Comparison` {bdg-info-line}`Correlation`
#
# :::
# ::::
#
# +++
#
# Credits:
# [DataVizProject](https://datavizproject.com/about/)
#
# ````

# %%
from mpl_chord_diagram import chord_diagram
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
name = ['A', 'B', 'C', 'D', 'E', 'F']
df = df = pd.DataFrame(np.random.randint(0,100,size=(6, 6)), columns=name, index=name)
df.head()
# Out:
#     A   B   C   D   E   F
# A  38  65  89   4  66  32
# B   0  40  22  71  61  50
# C  81  29  69  15  49   2
# D  84  50  44  57  26  22
# E  48  13  65  36  57  61

# %%
colors = ['#002855', '#FBD87F', '#023E7D', '#376996', '#829CBC', '#F8C23A']

chord_diagram(df, name, colors=colors, fig=(6, 6))
plt.show()
