# %% [markdown]
# # Scatter Chart
#
# ````{card}
#
# <br/>
#
# ::::{grid} 2
#
# :::{grid-item}
# :columns: 3
# :class: sd-m-auto
# <img src="../images/bubble.png" width="300px"/>
#
# :::
#
# :::{grid-item}
# :columns: 8
# Also called: Bubble Chart, Scatter Chart, Scattergram, Scatter Diagram, Scatter Graph
#
# A bubble chart is a type of chart that displays three dimensions of data. Each entity with its triplet (v1, v2, v3) of associated data is plotted as a disk that expresses two of the vi values through the disk’s xy location and the third through its size. Bubble charts can facilitate the understanding of social, economical, medical, and other scientific relationships. Bubble charts can be considered a variation of the scatter plot, in which the data points are replaced with bubbles.
#
# <br/>
#
# Functions:
#
# {bdg-info-line}`Comparison` {bdg-info-line}`Distribution` {bdg-info-line}`Correlation` {bdg-info-line}`Trend over time`
#
# :::
# ::::
#
# +++
#
# Credits:
# [DataVizProject](https://datavizproject.com/about/)
#
# ````

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
mpl.style.use('seaborn')
colors = ['#002855', '#023E7D', '#376996', '#829CBC', '#FBD87F', '#F8C23A']
fig = plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='sepal_length', y='sepal_width', size='petal_width', sizes=(1, 400), 
    hue='petal_length', palette=mpl.colors.ListedColormap(colors), alpha=0.6)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)
plt.show()
